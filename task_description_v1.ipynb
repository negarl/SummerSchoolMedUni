# %% [markdown]
# # Day #2: ISIC Dataset
#
# ### Hackaton
#
# **Date:** 9 - 11 Sept. 2026
#
# **Dataset(s) used:** https://www.isic-archive.com/
#
# ---
#
# **About this notebook:** The goal of this task is to expose you to a real-life dataset, with its own particular set of challenges. The used dataset is the ISIC Dataset.
# The ISIC Archive is a large, real-world biomedical imaging dataset assembled from many independent institutions and imaging devices over nearly a decade of contributions. Because it aggregates data from such varied sources, it exhibits many of the messy, practical challenges data curators face: inconsistent metadata fields, missing values, varying image quality and formats, class imbalance across diagnostic categories, and duplicate or near-duplicate entries from overlapping collection efforts. This makes it a good hands-on example for practicing core curation skills — assessing data quality, standardizing heterogeneous metadata, identifying and handling duplicates, and documenting a clear provenance trail — on a dataset with genuine, unscripted imperfections rather than a toy example.
#
# Since the dataset is widely varied (including different image types and modalities) and quite extensive (> 1.000.000 images), you will be working today in a sub-dataset curated by us.
#
# Your first task will be to **train a segmentation model to isolate the relevant lesion from dermatoscopic images**.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this session, participants will have:
#
# - [ ] Curated a real-life medical dataset.
# - [ ] Trained a segmentation model.
# - [ ] Generate a report using a LLM.

# %% [markdown]
# ## 0. Setup
#
#
# Folder Images
#
# Folder Segmentations
#
# metadata.csv

# %%
# How to access data?

# %% [markdown]
# ## 1 Loading & Inspecting the Data

# %% [markdown]
# ### 1.a Loading & Inspecting the Imaging Data
#
# Load the raw dataset and get a first look at its shape, structure, and types. We suggest printing random sets of images in order to adequately visualize a representative sample of images.
#
# **Hint**: Make sure to save a few images for your final presentation.

# %%
#Write your code here

# %% [markdown]
# ### 1.b Loading & Inspecting the Metadata
#
# Read the provided metadata and take a look at it. Get an idea of its general structure, what information is present and how it's determined. **Which columns do you think might be relevant for your problem/problems? (Based on the tasks listed on the Learning Objectives)**

# %%
#Write your code here

# %% [markdown]
# ## 2. Data Quality Assessment
#
# Identify issues *before* cleaning: missing values, duplicates, inconsistent types, outliers, encoding problems.
#
# Understand your task: Lesion segmentation in dermatoscopic images.
#
# **1. What have you noticed about the images?**
#
# **2. What issues are you expecting to arise?**
#
# **3. What do you consider to be basic requirements each image + metadata pair?**

# %%
#Write your code here

# %% [markdown]
# ## 3. Data Cleaning
#
# Address the issues found above: handle missing values, remove duplicates, fix types, standardize formats.
#
# **List here the issues you found and which you plan to address:**

# %%
# Write your code here

# %% [markdown]
# ## 4. Data Transformation & Standardization
#
# Reshape, rename, or map values to match a common schema or controlled vocabulary.
# Does your data need to be ordered? Renamed? What set up are you planning for inputting your data?

# %%
# Write yout code here

# %% [markdown]
# ## 5. Data Splits
#
# Create your data splits: train, validation, test.
#
# **Hint**: Remember to think of what unit you plan your split around!

# %%
# Write your code here

# %% [markdown]
# ## 6. Exporting the Curated Dataset
#
# Save the final dataset together with its documentation. Document what changes you made and any information you consider might be relevant.

# %%
# Write your code here

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise I
#
# Train a model that provides a segmentation mask for dermatoscopic images based on the provided data. Make sure to provide relevant performance metrics for the validation and test set.
#
# Target segmentation Dice Score: above 80%
#
# Suggested architectures: U-Net, ResNet(PyTorch/segmentation_models_pytorch), others
#
# Suggested libraries: PyTorch

# %%
# Write your code here

# %% [markdown]
# ### Exercise II
#
# #### Generating lesion reports with a Vision-Language Model (prompt engineering)
#
# **Goal:** Use an off-the-shelf medical Vision-Language Model (VLM) to generate short,
# structured, clinical-style reports for the dermatoscopic images in your curated dataset,
# and investigate how far prompt engineering alone can push report quality without any
# model fine-tuning.
#
# **Approach:** Experiment with prompt engineering techniques such as few-shot prompting,
# chain-of-thought prompting, and structured-output prompting (if supported by the model),
# either individually or combined. Compare the resulting reports across techniques to determine whether
# prompt engineering alone can meaningfully improve output quality relative to a
# zero-shot baseline, or whether fine-tuning remains necessary.

# %%
# ---  Define your prompt strategies -------------------------------------------------
PROMPTS = {
    "naive": {
        "system": None,
        "prompt": "Write a report for this image.",
    },
    # add "persona", "domain_grounding", "template", "decomposition", "few_shot", ...
}

# %% [markdown]
# ## Resources & Further Reading
